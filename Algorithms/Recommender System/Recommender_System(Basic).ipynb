# %% [markdown]
# <a href="https://colab.research.google.com/github/Kingcoder44/Machine-Learning/blob/main/Algorithms/Recommender%20System/Recommender_System(Basic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import numpy as np

# %%
columns_names=['user_id','item_id','rating','timestamp']

# %%
df=pd.read_csv('drive/MyDrive/u.data',sep='\t',names=columns_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53154 entries, 0 to 53153
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    53154 non-null  int64
#  1   item_id    53154 non-null  int64
#  2   rating     53154 non-null  int64
#  3   timestamp  53154 non-null  int64
# dtypes: int64(4)
# memory usage: 1.6 MB

# %%
movie=pd.read_csv('drive/MyDrive/Movie_Id_Titles')

# %%
movie.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df=pd.merge(df,movie,on='item_id')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set_style('white')

# %%
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Anna (1996)                               5.0
# Prefontaine (1997)                        5.0
# Boys, Les (1997)                          5.0
# Maya Lin: A Strong Clear Vision (1994)    5.0
# Delta of Venus (1994)                     5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             302
# Contact (1997)               279
# Fargo (1996)                 268
# Scream (1996)                266
# Return of the Jedi (1983)    259
# Name: rating, dtype: int64

# %%
ratings=pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.500000
# 101 Dalmatians (1996)      2.925926
# 12 Angry Men (1957)        4.333333
# 187 (1997)                 2.900000

# %%
ratings['num of ratings']=pd.DataFrame(df.groupby('title')['rating'].count())

# %%
ratings.head()
# Out:
#                              rating  numof ratings  num of ratings
# title
# 'Til There Was You (1997)  2.333333              6               6
# 1-900 (1994)               2.500000              2               2
# 101 Dalmatians (1996)      2.925926             54              54
# 12 Angry Men (1957)        4.333333             66              66
# 187 (1997)                 2.900000             20              20

# %%
ratings['num of ratings'].hist(bins=70)
# Out:
# <Axes: >

# %%
ratings['rating'].hist(bins=70)
# Out:
# <Axes: >

# %%
sns.jointplot(x='rating',y='num of ratings',alpha=0.6,data=ratings)
